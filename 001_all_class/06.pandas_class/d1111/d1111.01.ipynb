# %%
import pandas as pd
import numpy as np
df = pd.read_excel('score.xlsx',index_col='지원번호')
df
# Out:
#        이름    학교    키   국어   영어   수학  과학  사회        SW특기
# 지원번호
# 1번    강나래   구로고  197   90   85  100  95  85      Python
# 2번    강태원   구로고  184   40   35   50  55  25        Java
# 3번    강호림   구로고  168   80   75   70  80  75  Javascript
# 4번    김수찬   구로고  187   40   60   70  75  80         NaN
# 5번    김재욱   구로고  188   15   20   10  35  10         NaN
# 6번    박동현  디지털고  202   80  100   95  85  80           C
# 7번    박혜정  디지털고  188   55   65   45  40  35      PYTHON
# 8번    승근열  디지털고  190  100   85   90  95  95          C#

# %%
# 키 185 이상만 출력
filt = df['키']>=185
df[filt]
df[~filt]  # ~  부정
# Out:
#        이름   학교    키  국어  영어  수학  과학  사회        SW특기
# 지원번호
# 2번    강태원  구로고  184  40  35  50  55  25        Java
# 3번    강호림  구로고  168  80  75  70  80  75  Javascript

# %%
# 키 180 이상이면서, 학교가 구로고 학생을 출력하시오.
filt = (df['키']>=180) & (df['학교'] == '구로고')
df[filt]
# Out:
#        이름   학교    키  국어  영어   수학  과학  사회    SW특기
# 지원번호
# 1번    강나래  구로고  197  90  85  100  95  85  Python
# 2번    강태원  구로고  184  40  35   50  55  25    Java
# 4번    김수찬  구로고  187  40  60   70  75  80     NaN
# 5번    김재욱  구로고  188  15  20   10  35  10     NaN

# %%
# 키 180 이상이거나, 국어 점수가 60 이상인 학생을 출력히시오
filt = (df['키']>=180) | (df['국어']>=60)
df[filt]
# Out:
#        이름    학교    키   국어   영어   수학  과학  사회        SW특기
# 지원번호
# 1번    강나래   구로고  197   90   85  100  95  85      Python
# 2번    강태원   구로고  184   40   35   50  55  25        Java
# 3번    강호림   구로고  168   80   75   70  80  75  Javascript
# 4번    김수찬   구로고  187   40   60   70  75  80         NaN
# 5번    김재욱   구로고  188   15   20   10  35  10         NaN
# 6번    박동현  디지털고  202   80  100   95  85  80           C
# 7번    박혜정  디지털고  188   55   65   45  40  35      PYTHON
# 8번    승근열  디지털고  190  100   85   90  95  95          C#

# %%
# sw특기가 python,java 학생을 출력
langs = ['python','java']
# filt = df['SW특기'].isin(langs)   # isin(리스트타입)
filt = df['SW특기'].str.lower().isin(langs)   # isin(리스트타입)
df[filt]
# Out:
#        이름    학교    키  국어  영어   수학  과학  사회    SW특기
# 지원번호
# 1번    강나래   구로고  197  90  85  100  95  85  Python
# 2번    강태원   구로고  184  40  35   50  55  25    Java
# 7번    박혜정  디지털고  188  55  65   45  40  35  PYTHON

# %%
# java가 포함되어 있는 학생을 출력하시오.
# filt = (df['SW특기'].str.lower() == 'java')   # isin(리스트타입)

# contains
# 같은 글자만 비교해서 출력
filt = df['SW특기'].str.contains('Java',na=False)   # na = False : NaN데이터 False 처리
# 기존ㄷ ㅔ이터를 소문자 변환후 비교
filt = df['SW특기'].str.lower().str.contains('Java',na=False)   # na = False : NaN데이터 False 처리
df[filt]
# Out:
#        이름   학교    키  국어  영어  수학  과학  사회        SW특기
# 지원번호
# 2번    강태원  구로고  184  40  35  50  55  25        Java
# 3번    강호림  구로고  168  80  75  70  80  75  Javascript

# %% [markdown]
# * sort_values : 컬럼으로 정렬
# * sort_index : index로 정렬

# %%
# 키 컬럼을 순차정렬하시오.
# df.sort_values(컬럼이 들어옴)
df.sort_values('키')
df.sort_values('국어')
df.sort_values('영어',ascending=False) #  ascending=False 역순정렬
# Out:
#        이름    학교    키   국어   영어   수학  과학  사회        SW특기
# 지원번호
# 6번    박동현  디지털고  202   80  100   95  85  80           C
# 1번    강나래   구로고  197   90   85  100  95  85      Python
# 8번    승근열  디지털고  190  100   85   90  95  95          C#
# 3번    강호림   구로고  168   80   75   70  80  75  Javascript
# 7번    박혜정  디지털고  188   55   65   45  40  35      PYTHON
# 4번    김수찬   구로고  187   40   60   70  75  80         NaN
# 2번    강태원   구로고  184   40   35   50  55  25        Java
# 5번    김재욱   구로고  188   15   20   10  35  10         NaN

# %%
# index 정렬
df.sort_index() # 순차정렬
df.sort_index(ascending=False) # 역순정렬
# Out:
#        이름    학교    키   국어   영어   수학  과학  사회        SW특기
# 지원번호
# 1번    강나래   구로고  197   90   85  100  95  85      Python
# 2번    강태원   구로고  184   40   35   50  55  25        Java
# 3번    강호림   구로고  168   80   75   70  80  75  Javascript
# 4번    김수찬   구로고  187   40   60   70  75  80         NaN
# 5번    김재욱   구로고  188   15   20   10  35  10         NaN
# 6번    박동현  디지털고  202   80  100   95  85  80           C
# 7번    박혜정  디지털고  188   55   65   45  40  35      PYTHON
# 8번    승근열  디지털고  190  100   85   90  95  95          C#

# %%
# 컬럼 전체를 변경 - 해당되는 것을 찾아서 변경
df['학교'].replace({'구로고':'가산고'},inplace=True)
df
# Out:
#        이름    학교    키   국어   영어   수학  과학  사회        SW특기
# 지원번호
# 1번    강나래   가산고  197   90   85  100  95  85      Python
# 2번    강태원   가산고  184   40   35   50  55  25        Java
# 3번    강호림   가산고  168   80   75   70  80  75  Javascript
# 4번    김수찬   가산고  187   40   60   70  75  80         NaN
# 5번    김재욱   가산고  188   15   20   10  35  10         NaN
# 6번    박동현  디지털고  202   80  100   95  85  80           C
# 7번    박혜정  디지털고  188   55   65   45  40  35      PYTHON
# 8번    승근열  디지털고  190  100   85   90  95  95          C#

# %% [markdown]
# 컬럼값 변경은 컬럼에 값을 입력하면 값이 변경됨.

# %%
# 컬럼자체를 변경
# 해당 컬럼 값을 입력하면 변경됨.
df['SW특기'].str.lower()
df['SW특기']= df['SW특기'].str.lower()
df
# Out:
#        이름    학교    키   국어   영어   수학  과학  사회        SW특기
# 지원번호
# 1번    강나래   구로고  197   90   85  100  95  85      python
# 2번    강태원   구로고  184   40   35   50  55  25        java
# 3번    강호림   구로고  168   80   75   70  80  75  javascript
# 4번    김수찬   구로고  187   40   60   70  75  80         NaN
# 5번    김재욱   구로고  188   15   20   10  35  10         NaN
# 6번    박동현  디지털고  202   80  100   95  85  80           c
# 7번    박혜정  디지털고  188   55   65   45  40  35      python
# 8번    승근열  디지털고  190  100   85   90  95  95          c#

# %%
# 컬럼값 변경: 해당컬럼에 값을 입력하면 됨.
# 단, 타입이 같아야 한다.
df['학교'] = df['학교']+'등학교'

# 같은 타입만 더하기 가능
# df['키']+'cm' # 에러
# df['키'].astype(str) +'cm'  # 가능
# Out:
# 지원번호
# 1번    197cm
# 2번    184cm
# 3번    168cm
# 4번    187cm
# 5번    188cm
# 6번    202cm
# 7번    188cm
# 8번    190cm
# Name: 키, dtype: object

# %%
# 구로고 학생만 국어점수 50으로 변경
filt = df['학교'] == '구로고'
# 컬럼으로 비교하고 값의 변경은 row값을 찾아서 변경해야 함.
df.loc[filt,'국어'] =50
df
# Out:
#        이름    학교    키   국어   영어   수학  과학  사회        SW특기
# 지원번호
# 1번    강나래   구로고  197   50   85  100  95  85      Python
# 2번    강태원   구로고  184   50   35   50  55  25        Java
# 3번    강호림   구로고  168   50   75   70  80  75  Javascript
# 4번    김수찬   구로고  187   50   60   70  75  80         NaN
# 5번    김재욱   구로고  188   50   20   10  35  10         NaN
# 6번    박동현  디지털고  202   80  100   95  85  80           C
# 7번    박혜정  디지털고  188   55   65   45  40  35      PYTHON
# 8번    승근열  디지털고  190  100   85   90  95  95          C#

# %%
# 컬럼 추가
# 없는 컬럼명을 입력하면 추가됨
df['총합'] = df['국어']+df['영어']+df['수학']+df['과학']+df['사회']

# %%
c_list = list(df.columns)

# %%
# type(c_list[0:8]) # list
# type(c_list[-1]) # str
# [1,2]+[3,4] # list 타입을 맞춰서 더하기를 해야 함.

# %%
# 컬럼순서 변경 : 컬럼의 타입을 일치한 후 더하기를 해주면 됨.
# 리스트 + 리스트(문자열) + 리스트(문자열)
df = df[c_list[0:8]+[c_list[-1]]+[c_list[8]]]
df
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[110], line 3
#       1 # 컬럼순서 변경 : 컬럼의 타입을 일치한 후 더하기를 해주면 됨.
#       2 # 리스트 + 리스트(문자열) + 리스트(문자열)
# ----> 3 df = df[c_list[0:8]+[c_list[-1]]+[c_list[8]]]
#       4 df
#
# File c:\python\Lib\site-packages\pandas\core\frame.py:4108, in DataFrame.__getitem__(self, key)
#    4106     if is_iterator(key):
#    4107         key = list(key)
# -> 4108     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    4110 # take() does not accept boolean indexers
#    4111 if getattr(indexer, "dtype", None) == bool:
#
# File c:\python\Lib\site-packages\pandas\core\indexes\base.py:6200, in Index._get_indexer_strict(self, key, axis_name)
#    6197 else:
#    6198     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 6200 self._raise_if_missing(keyarr, indexer, axis_name)
#    6202 keyarr = self.take(indexer)
#    6203 if isinstance(key, Index):
#    6204     # GH 42790 - Preserve name from an Index
#
# File c:\python\Lib\site-packages\pandas\core\indexes\base.py:6252, in Index._raise_if_missing(self, key, indexer, axis_name)
#    6249     raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    6251 not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
# -> 6252 raise KeyError(f"{not_found} not in index")
#
# KeyError: "['총합'] not in index"

# %%
# 컬럼 전체 변경
# df['컬럼'] = 값

# %%
df['평균'] = df['총합']/5
c_list = list(df.columns)

# %%
# df['평균'] = df['총합']/5
df
# Out:
#        이름    학교    키   국어   영어   수학  과학  사회        SW특기   총합    평균
# 지원번호
# 1번    강나래   구로고  197   90   85  100  95  85      Python  455  91.0
# 2번    강태원   구로고  184   40   35   50  55  25        Java  205  41.0
# 3번    강호림   구로고  168   80   75   70  80  75  Javascript  380  76.0
# 4번    김수찬   구로고  187   40   60   70  75  80         NaN  325  65.0
# 5번    김재욱   구로고  188   15   20   10  35  10         NaN   90  18.0
# 6번    박동현  디지털고  202   80  100   95  85  80           C  440  88.0
# 7번    박혜정  디지털고  188   55   65   45  40  35      PYTHON  240  48.0
# 8번    승근열  디지털고  190  100   85   90  95  95          C#  465  93.0

# %%
# 평균 컬럼을 넣어서, 이름, 바로 뒤에 배치하시오.
# 없는 컬럼을 입력하면 추가, 있는 컬럼에 값을 입력하면 변경

df = df[[c_list[0]]+[c_list[-1]]+c_list[1:10]]
df
# Out:
#        이름    평균    학교    키   국어   영어   수학  과학  사회        SW특기   총합
# 지원번호
# 1번    강나래  91.0   구로고  197   90   85  100  95  85      Python  455
# 2번    강태원  41.0   구로고  184   40   35   50  55  25        Java  205
# 3번    강호림  76.0   구로고  168   80   75   70  80  75  Javascript  380
# 4번    김수찬  65.0   구로고  187   40   60   70  75  80         NaN  325
# 5번    김재욱  18.0   구로고  188   15   20   10  35  10         NaN   90
# 6번    박동현  88.0  디지털고  202   80  100   95  85  80           C  440
# 7번    박혜정  48.0  디지털고  188   55   65   45  40  35      PYTHON  240
# 8번    승근열  93.0  디지털고  190  100   85   90  95  95          C#  465

# %%
df
# Out:
#        이름   총합    학교    키   국어   영어   수학  과학  사회        SW특기   총합   결과
# 지원번호
# 1번    강나래  455   구로고  197   90   85  100  95  85      Python  455  불합격
# 2번    강태원  205   구로고  184   40   35   50  55  25        Java  205  불합격
# 3번    강호림  380   구로고  168   80   75   70  80  75  Javascript  380  불합격
# 4번    김수찬  325   구로고  187   40   60   70  75  80         NaN  325  불합격
# 5번    김재욱   90   구로고  188   15   20   10  35  10         NaN   90  불합격
# 6번    박동현  440  디지털고  202   80  100   95  85  80           C  440  불합격
# 7번    박혜정  240  디지털고  188   55   65   45  40  35      PYTHON  240  불합격
# 8번    승근열  465  디지털고  190  100   85   90  95  95          C#  465  불합격

# %%
# 결과 컬럼을 추가해서 평균 80점 이상, 합격, 불합격 출력하시오.
df['결과'] = '불합격'
filt = df['평균'] >= 80
df.loc[filt,'결과'] = '합격'
df
# Out:
# C:\Users\kosmo\AppData\Local\Temp\ipykernel_2512\63413964.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['결과'] = '불합격'
#        이름    평균    학교    키   국어   영어   수학  과학  사회        SW특기   총합   결과
# 지원번호
# 1번    강나래  91.0   구로고  197   90   85  100  95  85      Python  455   합격
# 2번    강태원  41.0   구로고  184   40   35   50  55  25        Java  205  불합격
# 3번    강호림  76.0   구로고  168   80   75   70  80  75  Javascript  380  불합격
# 4번    김수찬  65.0   구로고  187   40   60   70  75  80         NaN  325  불합격
# 5번    김재욱  18.0   구로고  188   15   20   10  35  10         NaN   90  불합격
# 6번    박동현  88.0  디지털고  202   80  100   95  85  80           C  440   합격
# 7번    박혜정  48.0  디지털고  188   55   65   45  40  35      PYTHON  240  불합격
# 8번    승근열  93.0  디지털고  190  100   85   90  95  95          C#  465   합격

# %%
# 컬럼 삭제 : drop(columns)
# index 삭제 : drop(index)
# df.drop(columns=['평균'],inplace=True)         # 1개 컬럼 삭제
df.drop(columns=['결과','총합'],inplace=True)   # 2개 컬럼 삭제
df
# Out:
# C:\Users\kosmo\AppData\Local\Temp\ipykernel_2512\2471086834.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop(columns=['결과','총합'],inplace=True)   # 2개 컬럼 삭제
#        이름    평균    학교    키   국어   영어   수학  과학  사회        SW특기
# 지원번호
# 1번    강나래  91.0   구로고  197   90   85  100  95  85      Python
# 2번    강태원  41.0   구로고  184   40   35   50  55  25        Java
# 3번    강호림  76.0   구로고  168   80   75   70  80  75  Javascript
# 4번    김수찬  65.0   구로고  187   40   60   70  75  80         NaN
# 5번    김재욱  18.0   구로고  188   15   20   10  35  10         NaN
# 6번    박동현  88.0  디지털고  202   80  100   95  85  80           C
# 7번    박혜정  48.0  디지털고  188   55   65   45  40  35      PYTHON
# 8번    승근열  93.0  디지털고  190  100   85   90  95  95          C#

# %%
## index 삭제 : drop(index), 적용 inplace = True
# df.drop(inde=['1번']) # index를 가지고 삭제
df.drop(index=['1번','3번']) # 2개를 삭제

# 수학 점수가 80점 이상 삭제
filt = df['수학'] <80
df.drop(index=df[filt].index,inplace=True)
df
# Out:
# C:\Users\kosmo\AppData\Local\Temp\ipykernel_2512\1307230115.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop(index=df[filt].index,inplace=True)
#        이름    평균    학교    키   국어   영어   수학  과학  사회    SW특기
# 지원번호
# 1번    강나래  91.0   구로고  197   90   85  100  95  85  Python
# 6번    박동현  88.0  디지털고  202   80  100   95  85  80       C
# 8번    승근열  93.0  디지털고  190  100   85   90  95  95      C#

# %%
## 컬럼에 해당되는 값을 다른 값으로 변경 : df.replace
## 컬럼값을 변경 : df[컬럼]
## 컬럼추가 : df[컬럼]
## 컬럼삭제 : df.drop(columns), df.drop(index)
## 컬럼의 특정값을 변경 : df.loc(조건,컬럼) = 값

# %%
# row 열을 추가
# 없는 index의 값을 가지고 입력 #df.index
df.loc['9번'] = ['홍길동','디지털고',191,100,89,87,67,90,'Django']
df
# Out:
#        이름    학교    키   국어   영어   수학  과학  사회        SW특기
# 지원번호
# 1번    강나래   구로고  197   90   85  100  95  85      Python
# 2번    강태원   구로고  184   40   35   50  55  25        Java
# 3번    강호림   구로고  168   80   75   70  80  75  Javascript
# 4번    김수찬   구로고  187   40   60   70  75  80         NaN
# 5번    김재욱   구로고  188   15   20   10  35  10         NaN
# 6번    박동현  디지털고  202   80  100   95  85  80           C
# 7번    박혜정  디지털고  188   55   65   45  40  35      PYTHON
# 8번    승근열  디지털고  190  100   85   90  95  95          C#
# 9번    홍길동  디지털고  191  100   89   87  67  90      Django

# %%
# row열 수정
# 있는 index에 값을 입력하면 수정이 됨.
df.loc['1번','국어'] = 80
df.loc['1번',['영어','수학']] = [100,99]
df
# Out:
#        이름    학교    키   국어   영어  수학  과학  사회        SW특기
# 지원번호
# 1번    강나래   구로고  197   80  100  99  95  85      Python
# 2번    강태원   구로고  184   40   35  50  55  25        Java
# 3번    강호림   구로고  168   80   75  70  80  75  Javascript
# 4번    김수찬   구로고  187   40   60  70  75  80         NaN
# 5번    김재욱   구로고  188   15   20  10  35  10         NaN
# 6번    박동현  디지털고  202   80  100  95  85  80           C
# 7번    박혜정  디지털고  188   55   65  45  40  35      PYTHON
# 8번    승근열  디지털고  190  100   85  90  95  95          C#
# 9번    홍길동  디지털고  191  100   89  87  67  90      Django

# %%
## index 삭제 : drop(index), 적용 inplace = True
# df.drop(inde=['1번']) # index를 가지고 삭제
df.drop(index=['1번','3번']) # 2개를 삭제
# Out:
#        이름    학교    키   국어   영어  수학  과학  사회    SW특기
# 지원번호
# 2번    강태원   구로고  184   40   35  50  55  25    Java
# 4번    김수찬   구로고  187   40   60  70  75  80     NaN
# 5번    김재욱   구로고  188   15   20  10  35  10     NaN
# 6번    박동현  디지털고  202   80  100  95  85  80       C
# 7번    박혜정  디지털고  188   55   65  45  40  35  PYTHON
# 8번    승근열  디지털고  190  100   85  90  95  95      C#
# 9번    홍길동  디지털고  191  100   89  87  67  90  Django

# %%
# row 추가 : 없는 index 값을 입력하면 추가
# row 수정 : 있는 index 값을 입력하면 수정
# 특정 컬럼의 값을 수정 : df.loc[조건,컬럼] = 값
# row 삭제 : df.drop(index=[인덱스번호])

# %%
# # 50점 이하에 있는 학생의 점수를 +20
# filt = df['국어']<50
# df.loc[filt,'국어'] = df.loc[filt,'국어']+20
# filt = df['국어']<50
# df.loc[filt,'국어'] = df.loc[filt,'국어']+10
# df
# Out:
#        이름    학교    키   국어   영어  수학  과학  사회        SW특기
# 지원번호
# 1번    강나래   구로고  197   80  100  99  95  85      Python
# 2번    강태원   구로고  184   60   35  50  55  25        Java
# 3번    강호림   구로고  168   80   75  70  80  75  Javascript
# 4번    김수찬   구로고  187   60   60  70  75  80         NaN
# 5번    김재욱   구로고  188   35   20  10  35  10         NaN
# 6번    박동현  디지털고  202   80  100  95  85  80           C
# 7번    박혜정  디지털고  188   55   65  45  40  35      PYTHON
# 8번    승근열  디지털고  190  100   85  90  95  95          C#
# 9번    홍길동  디지털고  191  100   89  87  67  90      Django

# %%
### 함수
def func(value):
  if value<50:
    return value+20
  else:
    return value

# 함수호출 : apply()
df['국어'] = df['국어'].apply(func)
df
# Out:
#        이름    학교    키   국어   영어   수학  과학  사회        SW특기
# 지원번호
# 1번    강나래   구로고  197   90   85  100  95  85      Python
# 2번    강태원   구로고  184   60   35   50  55  25        Java
# 3번    강호림   구로고  168   80   75   70  80  75  Javascript
# 4번    김수찬   구로고  187   60   60   70  75  80         NaN
# 5번    김재욱   구로고  188   55   20   10  35  10         NaN
# 6번    박동현  디지털고  202   80  100   95  85  80           C
# 7번    박혜정  디지털고  188   55   65   45  40  35      PYTHON
# 8번    승근열  디지털고  190  100   85   90  95  95          C#

# %%
# NaN 데이터 처리 : fillna : 입력, dropna : 삭제
df.fillna('python')  # inplace=True
# Out:
#        이름    학교    키   국어   영어   수학  과학  사회        SW특기
# 지원번호
# 1번    강나래   구로고  197   90   85  100  95  85      python
# 2번    강태원   구로고  184   60   35   50  55  25        java
# 3번    강호림   구로고  168   80   75   70  80  75  javascript
# 4번    김수찬   구로고  187   60   60   70  75  80      python
# 5번    김재욱   구로고  188   55   20   10  35  10      python
# 6번    박동현  디지털고  202   80  100   95  85  80           c
# 7번    박혜정  디지털고  188   55   65   45  40  35      python
# 8번    승근열  디지털고  190  100   85   90  95  95          c#

# %%
# Out:
#        이름    학교    키   국어   영어   수학  과학  사회        SW특기
# 지원번호
# 1번    강나래   구로고  197   90   85  100  95  85      python
# 2번    강태원   구로고  184   60   35   50  55  25        java
# 3번    강호림   구로고  168   80   75   70  80  75  javascript
# 4번    김수찬   구로고  187   60   60   70  75  80      python
# 5번    김재욱   구로고  188   55   20   10  35  10      python
# 6번    박동현  디지털고  202   80  100   95  85  80           c
# 7번    박혜정  디지털고  188   55   65   45  40  35      python
# 8번    승근열  디지털고  190  100   85   90  95  95          c#

# %%
# 1. 소문자로 취환
# 2. NaN 값에 python 데이터 입력
df['SW특기'] = df['SW특기'].str.lower()

# isnull : NaN 확인, isnotnull(): NaN아닌지 확인
filt = df['SW특기'].isnull()
df.loc[filt,'SW특기'] = 'python'
df
# Out:
#        이름    학교    키   국어   영어   수학  과학  사회        SW특기
# 지원번호
# 1번    강나래   구로고  197   90   85  100  95  85      python
# 2번    강태원   구로고  184   60   35   50  55  25        java
# 3번    강호림   구로고  168   80   75   70  80  75  javascript
# 4번    김수찬   구로고  187   60   60   70  75  80         NaN
# 5번    김재욱   구로고  188   55   20   10  35  10         NaN
# 6번    박동현  디지털고  202   80  100   95  85  80           c
# 7번    박혜정  디지털고  188   55   65   45  40  35      python
# 8번    승근열  디지털고  190  100   85   90  95  95          c#

# %%
### 함수
def func(value):
  if pd.notnull(value):
    return value.lower()
  else:
    return "python"
  pass

df['SW특기'] = df['SW특기'].apply(func)

# %%
df['국어'].astype(str).str.zfill(width=3)
# Out:
# 지원번호
# 1번    090
# 2번    040
# 3번    080
# 4번    040
# 5번    015
# 6번    080
# 7번    055
# 8번    100
# Name: 국어, dtype: object

# %%
# 함수를 사용해서 이름 첫글자를 제거해서 이름하시오.
def func(value):
  return value[1:3]

df['이름'] = df['이름'].apply(func)
df
# Out:
#       이름    학교    키   국어   영어   수학  과학  사회        SW특기
# 지원번호
# 1번    나래   구로고  197   90   85  100  95  85      Python
# 2번    태원   구로고  184   40   35   50  55  25        Java
# 3번    호림   구로고  168   80   75   70  80  75  Javascript
# 4번    수찬   구로고  187   40   60   70  75  80         NaN
# 5번    재욱   구로고  188   15   20   10  35  10         NaN
# 6번    동현  디지털고  202   80  100   95  85  80           C
# 7번    혜정  디지털고  188   55   65   45  40  35      PYTHON
# 8번    근열  디지털고  190  100   85   90  95  95          C#

# %%
import random

# %%
df
# Out:
#        이름    학교    키   국어   영어   수학  과학  사회        SW특기  요일
# 지원번호
# 1번    강나래   구로고  197   90   85  100  95  85      Python   0
# 2번    강태원   구로고  184   40   35   50  55  25        Java   0
# 3번    강호림   구로고  168   80   75   70  80  75  Javascript   0
# 4번    김수찬   구로고  187   40   60   70  75  80         NaN   0
# 5번    김재욱   구로고  188   15   20   10  35  10         NaN   0
# 6번    박동현  디지털고  202   80  100   95  85  80           C   0
# 7번    박혜정  디지털고  188   55   65   45  40  35      PYTHON   0
# 8번    승근열  디지털고  190  100   85   90  95  95          C#   0
# 요일      2     2    2    2    2    2   2   2           2   2

# %%
# 1. 요일 컬럼 추가
df['요일'] = 0
# 2. 0-6까지의 숫자를 랜덤으로 입력
for i in range(8):
  df.iloc[i,9] = random.randint(0,6)

# 함수를 사용해서 0-일, 1-월,2-화,....6-토요일로 변경하시오.
def func(value):
  if value == 0: return '일요일'
  elif value == 1: return '월요일'
  elif value == 2: return '화요일'
  elif value == 3: return '수요일'
  elif value == 4: return '목요일'
  elif value == 5: return '금요일'
  elif value == 6: return '토요일'

df['요일'] = df['요일'].apply(func)

df
# Out:
#        이름    학교    키   국어   영어   수학  과학  사회        SW특기   요일
# 지원번호
# 1번    강나래   구로고  197   90   85  100  95  85      Python  월요일
# 2번    강태원   구로고  184   40   35   50  55  25        Java  화요일
# 3번    강호림   구로고  168   80   75   70  80  75  Javascript  화요일
# 4번    김수찬   구로고  187   40   60   70  75  80         NaN  토요일
# 5번    김재욱   구로고  188   15   20   10  35  10         NaN  일요일
# 6번    박동현  디지털고  202   80  100   95  85  80           C  일요일
# 7번    박혜정  디지털고  188   55   65   45  40  35      PYTHON  화요일
# 8번    승근열  디지털고  190  100   85   90  95  95          C#  화요일

# %%
# str[:] : 문자슬라이싱
# str.split() : 분할 str.split(",")
# str.startswith() : 시작글자 인식  str.startswith('서울')
# str.endswith() : 끝글자 인식      str.endswith('.py')
# str.contains() : 포함글자 찾기    str.contains('s',na=False)
# str.find() : 문자위치 찾기        str.find('안')
# str.replace() : 문자 대체         str.replace(",":"")
# str.pad() : 문자열 패딩, 특정글자로 채워줌    str.pad(width=20,side='left',fillchar='_')
# str.zfill(): 0으로 채워줌         str.zfill(width=10)
# str.strip() : 공백 제거           
# str.lower() : 소문자 변경
# str.upper()  : 대문자 면경
# str.swapcase : 대소문자 변경
